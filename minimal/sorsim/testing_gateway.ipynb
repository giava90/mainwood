# %%
from py4j.java_gateway import JavaGateway 
gg = JavaGateway.launch_gateway(classpath="./SorSim4Python.jar", die_on_exit=True)

myclass_instance = gg.jvm.ch.wsl.sustfor.sorsim.python.SorSimEntryPoint()

# %%
result = myclass_instance.getSimpleWrapper()

# %%
result.getNumberOfTrees()
# Out:
# 384031

# %%
assortment = result.makeAssortments()
# Out:
# JavaObject id=o2

# %%
len(assortment), len(assortment[0])

# %%
import pandas as pd
# read the file Output.csv and store it in a dataframe
df=pd.read_csv('Output.csv', sep=';')
df.head()
# Out:
# C:\Users\giacomov\AppData\Local\Temp\ipykernel_24168\3588975704.py:3: DtypeWarning: Columns (1,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('Output.csv', sep=';')
#        #ID   Baum-ID Baumart Baumart-Code Beschrieb/BaumNr  \
# 0        1  118904.0   F�hre        102.0              NaN
# 1        2  118904.0   F�hre        102.0              NaN
# 2        3  118904.0   F�hre        102.0              NaN
# 3        4  118904.0   F�hre        102.0              NaN
# 4  #Summe:  118904.0   F�hre        102.0              NaN
#
#   Gruppierungsmerkmal  BHD [cm] Schaftl�nge [m] L�ngenklasse St�rkenklasse  \
# 0              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# 1              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# 2              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# 3              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# ...

# %%
df1=pd.read_csv('../interface_sorsim/Output.csv', sep=';')
df1.head()
# Out:
# C:\Users\giacomov\AppData\Local\Temp\ipykernel_24168\278445726.py:1: DtypeWarning: Columns (1,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1=pd.read_csv('../interface_sorsim/Output.csv', sep=';')
#        #ID   Baum-ID Baumart Baumart-Code Beschrieb/BaumNr  \
# 0        1  118904.0   F�hre        102.0              NaN
# 1        2  118904.0   F�hre        102.0              NaN
# 2        3  118904.0   F�hre        102.0              NaN
# 3        4  118904.0   F�hre        102.0              NaN
# 4  #Summe:  118904.0   F�hre        102.0              NaN
#
#   Gruppierungsmerkmal  BHD [cm] Schaftl�nge [m] L�ngenklasse St�rkenklasse  \
# 0              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# 1              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# 2              2057.0  8.104808           627.0   Restholz 1    Restholz 1
# ...
